# %% [markdown]
# # EXO Intro

# %%
import pandas as pd

# %%
df=pd.read_csv("Https://bit.ly/world-cities-clean")

# %%
df.head()
# Out:
#                name               country          subcountry  geonameid
# 0      les Escaldes               Andorra  Escaldes-Engordany    3040051
# 1  Andorra la Vella               Andorra    Andorra la Vella    3041563
# 2    Umm al Qaywayn  United Arab Emirates      Umm al Qaywayn     290594
# 3    Ras al-Khaimah  United Arab Emirates     Raʼs al Khaymah     291074
# 4      Khawr Fakkān  United Arab Emirates        Ash Shāriqah     291696

# %% [markdown]
# # Exo chemin non fonctionnel

# %%
df=pd.read_csv("chemin qui marche pas")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-3212520a812a> in <module>
# ----> 1 df=pd.read_csv("chemin qui marche pas")
#
# c:\users\anton\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %% [markdown]
# Fichier "chemin qui ne marche pas" n'existe pas
# On peut en déduire qu'il faut un chemin exact vers un fichier csv pour que cela marche.
# Cf l'éxo 1

# %% [markdown]
# #Exo chemin correct mais mauvais nom de colonnes

# %%
chemin="https://bit.ly/world-cities-dirty-v1"
data=pd.read_csv(chemin)
data.head()
# Out:
#        les Escaldes               Andorra Escaldes-Engordany  3040051
# 0  Andorra la Vella               Andorra   Andorra la Vella  3041563
# 1    Umm al Qaywayn  United Arab Emirates     Umm al Qaywayn   290594
# 2    Ras al-Khaimah  United Arab Emirates    Raʼs al Khaymah   291074
# 3      Khawr Fakkān  United Arab Emirates       Ash Shāriqah   291696
# 4             Dubai  United Arab Emirates              Dubai   292223

# %% [raw]
# Probleme = la premiere ligne devient les colonnes

# %%
#Solution

# %%
chemin="https://bit.ly/world-cities-dirty-v1"
data=pd.read_csv(chemin,names=["name","country","subcountry","geonameid"])
data.head()
# Out:
#                name               country          subcountry  geonameid
# 0      les Escaldes               Andorra  Escaldes-Engordany    3040051
# 1  Andorra la Vella               Andorra    Andorra la Vella    3041563
# 2    Umm al Qaywayn  United Arab Emirates      Umm al Qaywayn     290594
# 3    Ras al-Khaimah  United Arab Emirates     Raʼs al Khaymah     291074
# 4      Khawr Fakkān  United Arab Emirates        Ash Shāriqah     291696

# %%
chemin="https://bit.ly/world-cities-dirty-v2"
data=pd.read_csv(chemin)
data.head()
# Out:
#                                                                                                                                                                                                                                   Lorem ipsum dolor sit amet  \
# Sed ut perspiciatis unde omnis iste natus error...  totam rem aperiam    eaque ipsa quae ab illo inventore veritatis et...  sed quia consequuntur magni dolores eos qui ra...  qui dolorem ipsum quia dolor sit amet  consectetur             adipisci velit
# name                                               country              subcountry                                         geonameid                                          NaN                                    NaN                                 NaN
# ...

# %%
data.dropna()
# Out:
#                                                                                                                                                                                                                                 Lorem ipsum dolor sit amet  \
# Sed ut perspiciatis unde omnis iste natus error...  totam rem aperiam  eaque ipsa quae ab illo inventore veritatis et...  sed quia consequuntur magni dolores eos qui ra...  qui dolorem ipsum quia dolor sit amet  consectetur             adipisci velit
#
#                                                                                                                                                                                                                                                        consectetur adipiscing elit  \
# ...

# %%
data.dropna(axis=1,how='any')
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
data=pd.read_csv(chemin,skiprows=2,skipfooter=1,encoding='utf-8' )
data.head()
# Out:
# <ipython-input-36-d97aeb78981f>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data=pd.read_csv(chemin,skiprows=2,skipfooter=1,encoding='utf-8' )
#                name               country          subcountry  geonameid
# 0      les Escaldes               Andorra  Escaldes-Engordany    3040051
# 1  Andorra la Vella               Andorra    Andorra la Vella    3041563
# 2    Umm al Qaywayn  United Arab Emirates      Umm al Qaywayn     290594
# 3    Ras al-Khaimah  United Arab Emirates     Raʼs al Khaymah     291074
# 4      Khawr Fakkān  United Arab Emirates        Ash Shāriqah     291696

# %% [markdown]
# # solution

# %%
data=pd.read_csv(chemin,skiprows=2,skipfooter=1,encoding='utf-8' )
data.head()
# Out:
# <ipython-input-37-d97aeb78981f>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data=pd.read_csv(chemin,skiprows=2,skipfooter=1,encoding='utf-8' )
#                name               country          subcountry  geonameid
# 0      les Escaldes               Andorra  Escaldes-Engordany    3040051
# 1  Andorra la Vella               Andorra    Andorra la Vella    3041563
# 2    Umm al Qaywayn  United Arab Emirates      Umm al Qaywayn     290594
# 3    Ras al-Khaimah  United Arab Emirates     Raʼs al Khaymah     291074
# 4      Khawr Fakkān  United Arab Emirates        Ash Shāriqah     291696

# %% [markdown]
# ### EXO 4

# %%
chemin="https://bit.ly/world-cities-dirty-v3"
data=pd.read_csv(chemin)
data.head()
# Out:
#      les Escaldes|Andorra|Escaldes-Engordany|3040051
# 0  Andorra la Vella|Andorra|Andorra la Vella|3041563
# 1  Umm al Qaywayn|United Arab Emirates|Umm al Qay...
# 2  Ras al-Khaimah|United Arab Emirates|Raʼs al Kh...
# 3  Khawr Fakkān|United Arab Emirates|Ash Shāriqah...
# 4            Dubai|United Arab Emirates|Dubai|292223

# %% [raw]
# pb : mauvais delimiteur

# %%
chemin="https://bit.ly/world-cities-dirty-v3"
data=pd.read_csv(chemin,delimiter='|')
data.head()
# Out:
#        les Escaldes               Andorra Escaldes-Engordany  3040051
# 0  Andorra la Vella               Andorra   Andorra la Vella  3041563
# 1    Umm al Qaywayn  United Arab Emirates     Umm al Qaywayn   290594
# 2    Ras al-Khaimah  United Arab Emirates    Raʼs al Khaymah   291074
# 3      Khawr Fakkān  United Arab Emirates       Ash Shāriqah   291696
# 4             Dubai  United Arab Emirates              Dubai   292223

# %%
#SoLUTION

# %%
chemin="https://bit.ly/world-cities-dirty-v3"
data=pd.read_csv(chemin,delimiter='|')
data.head()
# Out:
#        les Escaldes               Andorra Escaldes-Engordany  3040051
# 0  Andorra la Vella               Andorra   Andorra la Vella  3041563
# 1    Umm al Qaywayn  United Arab Emirates     Umm al Qaywayn   290594
# 2    Ras al-Khaimah  United Arab Emirates    Raʼs al Khaymah   291074
# 3      Khawr Fakkān  United Arab Emirates       Ash Shāriqah   291696
# 4             Dubai  United Arab Emirates              Dubai   292223
